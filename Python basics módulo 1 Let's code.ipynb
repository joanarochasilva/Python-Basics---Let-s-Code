# %% [markdown]
# # <font color= "orange"> Atividades Módulo 1 - Let's Code

# %% [markdown]
# ### Joana Rocha da Silva

# %% [markdown]
# 1) Faça um programa que peça um valor monetário e diminua-o em 15%. Seu
# programa deve imprimir a mensagem “O novo valor é [valor]”.

# %%
ValorMonetario = float(input("Digite um valor: "))
VM =print("O novo valor é ", ValorMonetario - (ValorMonetario * 0.15))
# Out:
# Digite um valor: 20
# O novo valor é  17.0

# %% [markdown]
# 2) Faça um programa que leia a validade das informações:
#
# a. Idade: entre 0 e 150;
# b. Salário: maior que 0;
# c. Sexo: M, F ou Outro;
#
# O programa deve imprimir uma mensagem de erro para cada informação
# inválida.

# %%
idade = int(input("Insira a sua idade: "))
if idade<0 or idade>150:
    print("Informação inválida!")
salario = float(input("Insira seu salário: "))
if salario < 0:
    print("informação inválida!")   
sexo = input("Insira seu sexo (m, f ou outro): ")
if sexo == "m" or sexo == "f" or sexo =="outro":
    pass
else:
    print("Informação inválida!")
# Out:
# Insira a sua idade: 20
# Insira seu salário: 30
# Insira seu sexo (m, f ou outro): m

# %% [markdown]
# 3) Vamos fazer um programa para verificar quem é o assassino de um crime.
# Para descobrir o assassino, a polícia faz um pequeno questionário com 5
# perguntas onde a resposta só pode ser sim ou não:
#
# a. Mora perto da vítima?
# b. Já trabalhou com a vítima?
# c. Telefonou para a vítima?
# d. Esteve no local do crime?
# e. Devia para a vítima?
#
# Cada resposta sim dá um ponto para o suspeito. A polícia considera que os
# suspeitos com 5 pontos são os assassinos, com 4 a 3 pontos são cúmplices e
# 2 pontos são apenas suspeitos, necessitando outras investigações. Valores
# iguais ou abaixo de 1 são liberados.

# %%
contador = 0

P1 = input("Mora perto da vítima? (s ou n) ")
if P1 == "s":
    contador = contador + 1
elif P1 == "n":
    pass
elif P1 != "s" or "n":
    print("Resposta inválida!")
    
P2 = input("Já trabalhou com a vítima? (s ou n) ")
if P2 == "s":
    contador = contador + 1
elif P2 == "n":
    pass
elif P2 != "s" or "n":
    print("Resposta inválida!")

P3 = input("Telefonou para a vítima? (s ou n) ")
if P3 == "s":
    contador = contador + 1
elif P3 == "n":
    pass
elif P3 != "s" or "n":
    print("Resposta inválida!")

P4 = input("Esteve no local do crime? (s ou n) ")
if P4 == "s":
    contador = contador + 1
elif P4 == "n":
    pass
elif P4 != "s" or "n":
    print("Resposta inválida!")

P5 = input("Devia para a vítima? (s ou n) ")
if P5 == "s":
    contador = contador + 1
elif P5 == "n":
    pass
elif P5 != "s" or "n":
    print("Resposta inválida!")
    
print("A contagem de pontos é igual a: ", contador)
if contador == 5:
    print("Assassinos")
elif contador == 4 or contador == 3:
    print("Cúmplices")
elif contador == 2:
    print("Suspeitos. Novas investigações necessárias!")
elif contador <= 1:
    print("Liberados")
# Out:
# Mora perto da vítima? (s ou n) n
# Já trabalhou com a vítima? (s ou n) s
# Telefonou para a vítima? (s ou n) s
# Esteve no local do crime? (s ou n) s
# Devia para a vítima? (s ou n) s
# A contagem de pontos é igual a:  4
# Cúmplices

# %% [markdown]
# 4) Faça um programa que imprima a tabuada do 9 (de 9*1 a 9*10) usando loops

# %%
contador = 0

while contador < 11:
    valor = 9 * contador
    print("9 X ", contador, "=", valor)
    contador = contador + 1
# Out:
# 9 X  0 = 0
# 9 X  1 = 9
# 9 X  2 = 18
# 9 X  3 = 27
# 9 X  4 = 36
# 9 X  5 = 45
# 9 X  6 = 54
# 9 X  7 = 63
# 9 X  8 = 72
# 9 X  9 = 81
# 9 X  10 = 90
